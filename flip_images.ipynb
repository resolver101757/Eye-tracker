# %%
import os
import pandas as pd

# get list of files
files = os.listdir('G:\My Drive\Learning\data_science\datasets_toberenamed\gaze-points\work-laptop\depth_and_color_images')

# %%
from PIL import Image

for file in files:
    if file.endswith('.png'):
        img = Image.open(os.path.join('G:\\My Drive\\Learning\\data_science\\datasets_toberenamed\\gaze-points\\work-laptop\\depth_and_color_images', file))
        img_flipped = img.transpose(Image.FLIP_LEFT_RIGHT)
        img_flipped.save(os.path.join('G:\\My Drive\\Learning\\data_science\\datasets_toberenamed\\gaze-points\\work-laptop\\depth_and_color_images', file))
        print( file + ' saved')
# Out:
# 20240222-181317-hieght2560-width1440-computerwork-laptop-depth_606_271.png saved
# 20240222-181317-hieght2560-width1440-computerwork-laptop-colour_606_271.png saved
# 20240222-181318-hieght2560-width1440-computerwork-laptop-depth_151_678.png saved
# 20240222-181318-hieght2560-width1440-computerwork-laptop-colour_151_678.png saved
# 20240222-181319-hieght2560-width1440-computerwork-laptop-depth_723_310.png saved
# 20240222-181319-hieght2560-width1440-computerwork-laptop-colour_723_310.png saved
# 20240222-181319-hieght2560-width1440-computerwork-laptop-depth_558_870.png saved
# 20240222-181319-hieght2560-width1440-computerwork-laptop-colour_558_870.png saved
# 20240222-181321-hieght2560-width1440-computerwork-laptop-depth_1991_1015.png saved
# 20240222-181321-hieght2560-width1440-computerwork-laptop-colour_1991_1015.png saved
# 20240222-181321-hieght2560-width1440-computerwork-laptop-depth_886_1021.png saved
# ...
